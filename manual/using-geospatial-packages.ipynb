# %% [markdown]
# # Using packages from the geospatial-plus Python3 kernel
# update of 2021-09
#
# Some packages are more obvious than others--how to run them, import them, get started. Here we list a few that are a bit unusual.

# %% [markdown]
# ### Contents
# - [Installed Packages](#package-list)
# - [gdal](#gdal)
# - [scikit-image, scikit-learn](#scikit)
# - [geos](#geos)
# - [nco, cdo, and related](#cdo)
# - [geocat and related](#geocat)
# - [globus sdk](#globus)
# - [About your `$PATH`](#path)

# %% [markdown]
# <a href="package-list" id="package-list"></a>
# ## Installed packages
#
# The contents of the conda environment (env) behind our current running kernel (this listing includes packages installed via pip, too):

# %%
# !conda list -n geospatial-2021-09
# Out:
# # packages in environment at /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       1_gnu    conda-forge
# affine                    2.3.0                      py_0    conda-forge
# aiohttp                   3.7.4.post0              pypi_0    pypi
# alsa-lib                  1.2.3                h516909a_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argcomplete               1.12.3             pyhd8ed1ab_2    conda-forge
# argon2-cffi               20.1.0           py37h5e8e339_2    conda-forge
# asciitree                 0.3.3                      py_2    conda-forge
# async-timeout             3.0.1                    pypi_0    pypi
# async_generator           1.10                       py_0    conda-forge
# attrs                     21.2.0             pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backoff                   1.11.1             pyhd8ed1ab_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# binutils_impl_linux-64    2.36.1               h193b22a_2    conda-forge
# binutils_linux-64         2.36                 hf3e587d_1    conda-forge
# bleach                    4.1.0              pyhd8ed1ab_0    conda-forge
# blosc                     1.21.0               h9c3ff4c_0    conda-forge
# bokeh                     2.3.3            py37h89c1867_0    conda-forge
# boost-cpp                 1.74.0               hc6e9bd1_3    conda-forge
# boto3                     1.18.43                  pypi_0    pypi
# botocore                  1.21.43                  pypi_0    pypi
# bottleneck                1.3.2            py37hb1e94ed_4    conda-forge
# brotli                    1.0.9                h7f98852_5    conda-forge
# brotli-bin                1.0.9                h7f98852_5    conda-forge
# brotlipy                  0.7.0           py37h5e8e339_1001    conda-forge
# brunsli                   0.1                  h9c3ff4c_0    conda-forge
# bzip2                     1.0.8                h7f98852_4    conda-forge
# c-ares                    1.17.2               h7f98852_0    conda-forge
# ca-certificates           2021.5.30            ha878542_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cairo                     1.16.0            h6cf1ce9_1008    conda-forge
# carst                     2.0.0a1                  pypi_0    pypi
# cartopy                   0.19.0.post1     py37h0c48da3_1    conda-forge
# cdo                       1.9.9               had776b3_14    conda-forge
# certifi                   2021.5.30        py37h89c1867_0    conda-forge
# cf_xarray                 0.6.1              pyh6c4a22f_0    conda-forge
# cffi                      1.14.6           py37hc58025e_0    conda-forge
# cfitsio                   3.470                hb418390_7    conda-forge
# cftime                    1.5.0            py37h6f94858_0    conda-forge
# chardet                   4.0.0            py37h89c1867_1    conda-forge
# charls                    2.2.0                h9c3ff4c_0    conda-forge
# click                     7.1.2              pyh9f0ad1d_0    conda-forge
# click-plugins             1.1.1                      py_0    conda-forge
# cligj                     0.7.2              pyhd8ed1ab_0    conda-forge
# cloudpickle               2.0.0              pyhd8ed1ab_0    conda-forge
# cmaps                     1.0.4              pyh6c4a22f_0    conda-forge
# colorama                  0.4.4              pyh9f0ad1d_0    conda-forge
# colorcet                  2.0.6              pyhd8ed1ab_0    conda-forge
# cryptography              3.4.7            py37h5d9358c_0    conda-forge
# curl                      7.75.0               h979ede3_0    conda-forge
# cycler                    0.10.0                     py_2    conda-forge
# cytoolz                   0.11.0           py37h5e8e339_3    conda-forge
# dask                      2021.9.0           pyhd8ed1ab_0    conda-forge
# dask-core                 2021.9.0           pyhd8ed1ab_0    conda-forge
# datashader                0.13.0             pyh6c4a22f_0    conda-forge
# datashape                 0.5.4                      py_1    conda-forge
# dbus                      1.13.6               h48d8840_2    conda-forge
# debugpy                   1.4.1            py37hcd2ae1e_0    conda-forge
# decorator                 5.1.0              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# distributed               2021.9.0         py37h89c1867_0    conda-forge
# eccodes                   2.21.0               ha0e6eb6_0    conda-forge
# entrypoints               0.3             pyhd8ed1ab_1003    conda-forge
# eofs                      1.4.0                      py_0    conda-forge
# esmf                      8.1.0           nompi_hed08645_0    conda-forge
# et-xmlfile                1.1.0                    pypi_0    pypi
# expat                     2.4.1                h9c3ff4c_0    conda-forge
# fasteners                 0.16               pyhd8ed1ab_0    conda-forge
# ffmpeg                    4.3.2                hca11adc_0    conda-forge
# fftw                      3.3.9           nompi_h74d3f13_101    conda-forge
# filelock                  3.0.12             pyh9f0ad1d_0    conda-forge
# fiona                     1.8.18           py37h17d6ad9_1    conda-forge
# flask                     2.0.1                    pypi_0    pypi
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 hab24e00_0    conda-forge
# fontconfig                2.13.1            hba837de_1005    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# freetype                  2.10.4               h0708190_1    conda-forge
# freexl                    1.0.6                h7f98852_0    conda-forge
# fsspec                    2021.8.1           pyhd8ed1ab_0    conda-forge
# gcc_impl_linux-64         11.2.0               h82a94d6_8    conda-forge
# gcc_linux-64              11.2.0               h39a9532_1    conda-forge
# gdal                      3.2.1            py37hc5bc4e4_7    conda-forge
# geocat-comp               2021.09.0                  py_0    ncar
# geocat-f2py               2021.08.0        py37h3d0eb6f_0    ncar
# geocat-viz                2020.7.30.1        pyh39e3cac_0    ncar
# geopandas                 0.9.0              pyhd8ed1ab_1    conda-forge
# geopandas-base            0.9.0              pyhd8ed1ab_1    conda-forge
# georaster                 1.27               pyh9f0ad1d_0    conda-forge
# geos                      0.2.3                    pypi_0    pypi
# geotiff                   1.6.0                h2b14fbe_4    conda-forge
# geoviews                  1.9.1              pyhd8ed1ab_1    conda-forge
# geoviews-core             1.9.1              pyha770c72_1    conda-forge
# gettext                   0.19.8.1          h0b5b191_1005    conda-forge
# gfortran_impl_linux-64    11.2.0               h7a446d4_8    conda-forge
# gfortran_linux-64         11.2.0               h777b47f_1    conda-forge
# giflib                    5.2.1                h36c2ea0_2    conda-forge
# glib                      2.68.4               h9c3ff4c_0    conda-forge
# glib-tools                2.68.4               h9c3ff4c_0    conda-forge
# globus-sdk                3.0.1                    pypi_0    pypi
# gmp                       6.2.1                h58526e2_0    conda-forge
# gnutls                    3.6.13               h85f3911_1    conda-forge
# graphite2                 1.3.13            h58526e2_1001    conda-forge
# gsl                       2.6                  he838d99_2    conda-forge
# gst-plugins-base          1.18.5               hf529b03_0    conda-forge
# gstreamer                 1.18.5               h76c114f_0    conda-forge
# h5netcdf                  0.11.0                   pypi_0    pypi
# h5py                      3.3.0           nompi_py37ha3df211_100    conda-forge
# harfbuzz                  2.9.1                h83ec7ef_0    conda-forge
# hdf4                      4.2.15               h10796ff_3    conda-forge
# hdf5                      1.10.6          nompi_h6a2412b_1114    conda-forge
# heapdict                  1.0.1                      py_0    conda-forge
# holoviews                 1.14.5             pyhd8ed1ab_0    conda-forge
# hublib                    0.9.96                   pypi_0    pypi
# hvplot                    0.7.3              pyh6c4a22f_0    conda-forge
# icepyx                    0.4.0              pyhd8ed1ab_0    conda-forge
# icu                       68.1                 h58526e2_0    conda-forge
# idna                      2.10               pyh9f0ad1d_0    conda-forge
# imagecodecs               2021.3.31        py37haf4b6ec_0    conda-forge
# imageio                   2.9.0                      py_0    conda-forge
# importlib-metadata        4.8.1            py37h89c1867_0    conda-forge
# importlib_metadata        4.8.1                hd8ed1ab_0    conda-forge
# importlib_resources       5.2.2              pyhd8ed1ab_0    conda-forge
# intake                    0.6.3              pyhd8ed1ab_0    conda-forge
# intake-stac               0.3.0                      py_0    conda-forge
# intake-xarray             0.5.0              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.4.1            py37h6531663_0    conda-forge
# ipyleaflet                0.14.0                   pypi_0    pypi
# ipympl                    0.7.0                    pypi_0    pypi
# ipython                   7.27.0           py37h6531663_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                7.6.5              pyhd8ed1ab_0    conda-forge
# isce2                     2.5.1            py37h244a3d2_2    conda-forge
# itsdangerous              2.0.1                    pypi_0    pypi
# jasper                    1.900.1           h07fcdf6_1006    conda-forge
# jedi                      0.18.0           py37h89c1867_2    conda-forge
# jinja2                    3.0.1              pyhd8ed1ab_0    conda-forge
# jmespath                  0.10.0                   pypi_0    pypi
# joblib                    1.0.1              pyhd8ed1ab_0    conda-forge
# jpeg                      9d                   h36c2ea0_0    conda-forge
# json-c                    0.15                 h98cffda_0    conda-forge
# jsonschema                3.2.0              pyhd8ed1ab_3    conda-forge
# jupyter_client            7.0.2              pyhd8ed1ab_0    conda-forge
# jupyter_core              4.8.1            py37h89c1867_0    conda-forge
# jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
# jupyterlab_widgets        1.0.2              pyhd8ed1ab_0    conda-forge
# jxrlib                    1.1                  h7f98852_2    conda-forge
# kealib                    1.4.14               hcc255d8_2    conda-forge
# kernel-headers_linux-64   2.6.32              he073ed8_14    conda-forge
# kiwisolver                1.3.2            py37h2527ec5_0    conda-forge
# krb5                      1.17.2               h926e7f8_0    conda-forge
# lame                      3.100             h7f98852_1001    conda-forge
# lcms2                     2.12                 hddcbb42_0    conda-forge
# ld_impl_linux-64          2.36.1               hea4e1c9_2    conda-forge
# lerc                      2.2.1                h9c3ff4c_0    conda-forge
# libaec                    1.0.5                h9c3ff4c_0    conda-forge
# libblas                   3.9.0           11_linux64_openblas    conda-forge
# libbrotlicommon           1.0.9                h7f98852_5    conda-forge
# libbrotlidec              1.0.9                h7f98852_5    conda-forge
# libbrotlienc              1.0.9                h7f98852_5    conda-forge
# libcblas                  3.9.0           11_linux64_openblas    conda-forge
# libclang                  11.1.0          default_ha53f305_1    conda-forge
# libcurl                   7.75.0               hc4aaa36_0    conda-forge
# libdap4                   3.20.6               hd7c4107_2    conda-forge
# libdeflate                1.7                  h7f98852_5    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 h516909a_1    conda-forge
# libevent                  2.1.10               hcdb4288_3    conda-forge
# libffi                    3.3                  h58526e2_2    conda-forge
# libgcc-devel_linux-64     11.2.0               h0952999_8    conda-forge
# libgcc-ng                 11.2.0               h1d223b6_8    conda-forge
# libgdal                   3.2.1                h38ff51b_7    conda-forge
# libgfortran-ng            11.2.0               h69a702a_8    conda-forge
# libgfortran5              11.2.0               h5c6108e_8    conda-forge
# libglib                   2.68.4               h3e27bee_0    conda-forge
# libgomp                   11.2.0               h1d223b6_8    conda-forge
# libiconv                  1.16                 h516909a_0    conda-forge
# libkml                    1.3.0             h238a007_1014    conda-forge
# liblapack                 3.9.0           11_linux64_openblas    conda-forge
# liblapacke                3.9.0           11_linux64_openblas    conda-forge
# libllvm10                 10.0.1               he513fc3_3    conda-forge
# libllvm11                 11.1.0               hf817b99_2    conda-forge
# libnetcdf                 4.7.4           nompi_h56d31a8_107    conda-forge
# libnghttp2                1.43.0               h812cca2_0    conda-forge
# libogg                    1.3.4                h7f98852_1    conda-forge
# libopenblas               0.3.17          pthreads_h8fe5266_1    conda-forge
# libopencv                 4.5.2            py37h8945300_0    conda-forge
# libopus                   1.3.1                h7f98852_1    conda-forge
# libpng                    1.6.37               h21135ba_2    conda-forge
# libpq                     13.2                 hfd2b0eb_2    conda-forge
# libprotobuf               3.15.8               h780b84a_1    conda-forge
# librttopo                 1.1.0                h1185371_6    conda-forge
# libsanitizer              11.2.0               he4da1e4_8    conda-forge
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libspatialindex           1.9.3                h9c3ff4c_4    conda-forge
# libspatialite             5.0.1                he52d314_3    conda-forge
# libssh2                   1.10.0               ha56f1ee_0    conda-forge
# libstdcxx-ng              11.2.0               he4da1e4_8    conda-forge
# libtiff                   4.2.0                hbd63e13_2    conda-forge
# libuuid                   2.32.1            h7f98852_1000    conda-forge
# libuv                     1.42.0               h7f98852_0    conda-forge
# libvorbis                 1.3.7                h9c3ff4c_0    conda-forge
# libwebp-base              1.2.1                h7f98852_0    conda-forge
# libxcb                    1.13              h7f98852_1003    conda-forge
# libxkbcommon              1.0.3                he3ba5ed_0    conda-forge
# libxml2                   2.9.12               h72842e0_0    conda-forge
# libzopfli                 1.0.3                h9c3ff4c_0    conda-forge
# llvmlite                  0.36.0           py37h9d7f4d0_0    conda-forge
# locket                    0.2.0                      py_2    conda-forge
# lxml                      4.6.3                    pypi_0    pypi
# lz4-c                     1.9.3                h9c3ff4c_1    conda-forge
# mapclassify               2.4.3              pyhd8ed1ab_0    conda-forge
# markdown                  3.3.4              pyhd8ed1ab_0    conda-forge
# markupsafe                2.0.1            py37h5e8e339_0    conda-forge
# matplotlib                3.4.3            py37h89c1867_0    conda-forge
# matplotlib-base           3.4.3            py37h1058ff1_0    conda-forge
# matplotlib-inline         0.1.3              pyhd8ed1ab_0    conda-forge
# metpy                     1.1.0              pyhd8ed1ab_0    conda-forge
# mistune                   0.8.4           py37h5e8e339_1004    conda-forge
# monotonic                 1.5                        py_0    conda-forge
# msgpack-python            1.0.2            py37h2527ec5_1    conda-forge
# multidict                 5.1.0                    pypi_0    pypi
# multipledispatch          0.6.0                      py_0    conda-forge
# munch                     2.5.0                      py_0    conda-forge
# mysql-common              8.0.25               ha770c72_0    conda-forge
# mysql-libs                8.0.25               h935591d_0    conda-forge
# nbclient                  0.5.4              pyhd8ed1ab_0    conda-forge
# nbconvert                 6.1.0            py37h89c1867_1    conda-forge
# nbformat                  5.1.3              pyhd8ed1ab_0    conda-forge
# nco                       4.9.8                he39ba57_1    conda-forge
# ncurses                   6.2                  h58526e2_4    conda-forge
# nest-asyncio              1.5.1              pyhd8ed1ab_0    conda-forge
# netcdf-fortran            4.5.3           nompi_h996563d_103    conda-forge
# netcdf4                   1.5.6           nompi_py37hf7b6e46_102    conda-forge
# nettle                    3.6                  he412f7d_0    conda-forge
# networkx                  2.5                        py_0    conda-forge
# nodejs                    16.6.1               h92b4a50_0    conda-forge
# notebook                  6.4.4              pyha770c72_0    conda-forge
# nspr                      4.30                 h9c3ff4c_0    conda-forge
# nss                       3.69                 hb5efdd6_0    conda-forge
# numba                     0.53.1           py37hb11d6e1_1    conda-forge
# numcodecs                 0.9.1            py37hcd2ae1e_0    conda-forge
# numpy                     1.21.2           py37h31617e3_0    conda-forge
# olefile                   0.46               pyh9f0ad1d_1    conda-forge
# opencv                    4.5.2            py37h89c1867_0    conda-forge
# openh264                  2.1.1                h780b84a_0    conda-forge
# openjpeg                  2.4.0                hb52868f_1    conda-forge
# openmotif                 2.3.8                ha85b609_2    conda-forge
# openpyxl                  3.0.8                    pypi_0    pypi
# openssl                   1.1.1l               h7f98852_0    conda-forge
# ossuuid                   1.6.2             hf484d3e_1000    conda-forge
# packaging                 21.0               pyhd8ed1ab_0    conda-forge
# pandas                    1.3.3            py37he8f5f7f_0    conda-forge
# pandoc                    2.14.2               h7f98852_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# panel                     0.12.1             pyhd8ed1ab_0    conda-forge
# param                     1.11.1             pyh6c4a22f_0    conda-forge
# parso                     0.8.2              pyhd8ed1ab_0    conda-forge
# partd                     1.2.0              pyhd8ed1ab_0    conda-forge
# pcre                      8.45                 h9c3ff4c_0    conda-forge
# pexpect                   4.8.0              pyh9f0ad1d_2    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    8.2.0            py37h4600e1f_1    conda-forge
# pint                      0.17               pyhd8ed1ab_1    conda-forge
# pip                       21.2.4             pyhd8ed1ab_0    conda-forge
# pixman                    0.40.0               h36c2ea0_0    conda-forge
# pooch                     1.5.1              pyhd8ed1ab_0    conda-forge
# poppler                   0.89.0               h2de54a5_5    conda-forge
# poppler-data              0.4.11               hd8ed1ab_0    conda-forge
# postgresql                13.2                 h6303168_2    conda-forge
# progressbar2              3.53.3                   pypi_0    pypi
# proj                      7.2.0                h277dcde_2    conda-forge
# prometheus_client         0.11.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.20             pyha770c72_0    conda-forge
# properscoring             0.1                        py_0    conda-forge
# psutil                    5.8.0            py37h5e8e339_1    conda-forge
# pthread-stubs             0.4               h36c2ea0_1001    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# py-opencv                 4.5.2            py37h085eea5_0    conda-forge
# pycparser                 2.20               pyh9f0ad1d_2    conda-forge
# pyct                      0.4.6                      py_0    conda-forge
# pyct-core                 0.4.6                      py_0    conda-forge
# pygments                  2.10.0             pyhd8ed1ab_0    conda-forge
# pyjwt                     2.1.0                    pypi_0    pypi
# pynco                     1.0.0                      py_1    conda-forge
# pyopenssl                 20.0.1             pyhd8ed1ab_0    conda-forge
# pyparsing                 2.4.7              pyh9f0ad1d_0    conda-forge
# pyproj                    3.1.0            py37h20b8899_3    conda-forge
# pyqt                      5.12.3           py37h89c1867_7    conda-forge
# pyqt-impl                 5.12.3           py37he336c9b_7    conda-forge
# pyqt5-sip                 4.19.18          py37hcd2ae1e_7    conda-forge
# pyqtchart                 5.12             py37he336c9b_7    conda-forge
# pyqtwebengine             5.12.1           py37he336c9b_7    conda-forge
# pyrsistent                0.17.3           py37h5e8e339_2    conda-forge
# pyshp                     2.1.3              pyh44b312d_0    conda-forge
# pysocks                   1.7.1            py37h89c1867_3    conda-forge
# python                    3.7.7                hcff3b4d_5
# python-dateutil           2.7.5                      py_0    conda-forge
# python-utils              2.5.6                    pypi_0    pypi
# python_abi                3.7                     2_cp37m    conda-forge
# pytz                      2021.1             pyhd8ed1ab_0    conda-forge
# pyviz_comms               2.1.0              pyhd8ed1ab_0    conda-forge
# pywavelets                1.1.1            py37hb1e94ed_3    conda-forge
# pyyaml                    5.4.1            py37h5e8e339_1    conda-forge
# pyzmq                     22.3.0           py37h336d617_0    conda-forge
# qt                        5.12.9               hda022c4_4    conda-forge
# rasterio                  1.2.6            py37hd5c4cce_0    conda-forge
# rasterstats               0.15.0             pyhd8ed1ab_0    conda-forge
# readline                  8.1                  h46c0cb4_0    conda-forge
# requests                  2.25.1             pyhd3deb0d_0    conda-forge
# rioxarray                 0.7.0              pyhd8ed1ab_0    conda-forge
# rtree                     0.9.7            py37h0b55af0_2    conda-forge
# s3transfer                0.5.0                    pypi_0    pypi
# sat-search                0.3.0                      py_0    conda-forge
# sat-stac                  0.4.1              pyh44b312d_0    conda-forge
# scikit-image              0.18.3           py37he8f5f7f_0    conda-forge
# scikit-learn              0.24.2           py37hf0f1638_1    conda-forge
# scipy                     1.7.1            py37hf2a6cf1_0    conda-forge
# send2trash                1.8.0              pyhd8ed1ab_0    conda-forge
# setuptools                58.0.4           py37h89c1867_0    conda-forge
# shapely                   1.7.1            py37h48c49eb_5    conda-forge
# simplejson                3.17.5           py37h5e8e339_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# snappy                    1.1.8                he1b5a44_3    conda-forge
# snuggs                    1.4.7                      py_0    conda-forge
# sortedcontainers          2.4.0              pyhd8ed1ab_0    conda-forge
# sqlite                    3.36.0               h9cd32fc_1    conda-forge
# sysroot_linux-64          2.12                he073ed8_14    conda-forge
# tblib                     1.7.0              pyhd8ed1ab_0    conda-forge
# tempest-remap             2.0.5                h1b20e2d_0    conda-forge
# terminado                 0.12.1           py37h89c1867_0    conda-forge
# testpath                  0.5.0              pyhd8ed1ab_0    conda-forge
# threadpoolctl             2.2.0              pyh8a188c0_0    conda-forge
# tifffile                  2021.4.8           pyhd8ed1ab_0    conda-forge
# tiledb                    2.2.9                h91fcb0e_0    conda-forge
# tk                        8.6.11               h27826a3_1    conda-forge
# toolz                     0.11.1                     py_0    conda-forge
# tornado                   6.1              py37h5e8e339_1    conda-forge
# tqdm                      4.62.2             pyhd8ed1ab_0    conda-forge
# traitlets                 5.1.0              pyhd8ed1ab_0    conda-forge
# traittypes                0.2.1                    pypi_0    pypi
# typing_extensions         3.10.0.0           pyha770c72_0    conda-forge
# tzcode                    2021a                h7f98852_2    conda-forge
# tzdata                    2021a                he74cb21_1    conda-forge
# udunits2                  2.2.27.27            hc3e0081_2    conda-forge
# urllib3                   1.26.6             pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# werkzeug                  2.0.1                    pypi_0    pypi
# wheel                     0.37.0             pyhd8ed1ab_1    conda-forge
# widgetsnbextension        3.5.1            py37h89c1867_4    conda-forge
# x264                      1!161.3030           h7f98852_1    conda-forge
# xarray                    0.19.0             pyhd8ed1ab_1    conda-forge
# xerces-c                  3.2.3                h9d8b166_2    conda-forge
# xhistogram                0.3.0              pyhd8ed1ab_0    conda-forge
# xlrd                      2.0.1                    pypi_0    pypi
# xorg-kbproto              1.0.7             h7f98852_1002    conda-forge
# xorg-libice               1.0.10               h7f98852_0    conda-forge
# xorg-libsm                1.2.3             hd9c2040_1000    conda-forge
# xorg-libx11               1.6.12               h36c2ea0_0    conda-forge
# xorg-libxau               1.0.9                h7f98852_0    conda-forge
# xorg-libxdmcp             1.1.3                h7f98852_0    conda-forge
# xorg-libxext              1.3.4                h516909a_0    conda-forge
# xorg-libxft               2.3.4                h8aea5ac_0    conda-forge
# xorg-libxmu               1.1.3                h516909a_0    conda-forge
# xorg-libxp                1.0.3                         0    conda-forge
# xorg-libxrender           0.9.10            h516909a_1002    conda-forge
# xorg-libxt                1.1.5             h516909a_1003    conda-forge
# xorg-renderproto          0.11.1            h7f98852_1002    conda-forge
# xorg-xextproto            7.3.0             h7f98852_1002    conda-forge
# xorg-xproto               7.0.31            h7f98852_1007    conda-forge
# xskillscore               0.0.23             pyhd8ed1ab_0    conda-forge
# xz                        5.2.5                h516909a_1    conda-forge
# yaml                      0.2.5                h516909a_0    conda-forge
# yarl                      1.6.3                    pypi_0    pypi
# zarr                      2.9.5              pyhd8ed1ab_0    conda-forge
# zeromq                    4.3.4                h9c3ff4c_1    conda-forge
# zfp                       0.5.5                h9c3ff4c_6    conda-forge
# zict                      2.0.0                      py_0    conda-forge
# zipp                      3.5.0              pyhd8ed1ab_0    conda-forge
# zlib                      1.2.11            h516909a_1010    conda-forge
# zstd                      1.4.9                ha95c52a_0    conda-forge

# %% [markdown]
# <a href="gdal" id="gdal"></a>
# ## How to use gdal and friends (osgeo, ogr, osr)

# %% [markdown]
# per https://opensourceoptions.com/blog/how-to-install-gdal-with-anaconda/

# %% [markdown]
# Suppose you want to use the `gdal` package. Your first instinct will be to type `import gdal`, but this will produce the error shown below.
#
# ```ModuleNotFoundError: No module named 'gdal'```
#
# Not to worry. The GDAL distribution from conda-forge installs GDAL as part of the OSGEO library, which includes GDAL, OGR, and OSR. Just use, instead:
#
# ```from osgeo import gdal```

# %%
# this will err out:
# import gdal

# %%
# instead do this for gdal:
from osgeo import gdal

# %%
# and for ogr:
from osgeo import ogr

# %%
# and likewise for osr:
from osgeo import osr

# %% [markdown]
# <a href="scikit" id="scikit"></a>
# ## Using `scikit-image` and `scikit-learn`
#
# The syntax for importing these packages may not be what you expect; it's different from the name. This seems to be common in Python packages!
#
# https://scikit-learn.org/stable/
#
# https://scikit-image.org/

# %%
# this doesn't do it:
#import scikit-learn

# %% [markdown]
# `import scikit-learn`
#
# gives us:
#
# ```SyntaxError: invalid syntax```

# %% [markdown]
# Instead, use `sklearn` for the package name:

# %%
import sklearn

# %%
sklearn.show_versions()
# Out:
# System:
#     python: 3.7.7 (default, May  7 2020, 21:25:33)  [GCC 7.3.0]
# executable: /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/bin/python
#    machine: Linux-3.10.0-1160.31.1.el7.x86_64-x86_64-with-debian-10.5
#
# Python dependencies:
#           pip: 21.2.4
#    setuptools: 58.0.4
#       sklearn: 0.24.2
#         numpy: 1.21.2
#         scipy: 1.7.1
#        Cython: None
#        pandas: 1.3.3
#    matplotlib: 3.4.3
#        joblib: 1.0.1
# threadpoolctl: 2.2.0
#
# Built with OpenMP: True

# %% [markdown]
# And, `skimage` for the other package name:

# %%
# and for scikit-image
import skimage
print(skimage.__version__)
# Out:
# 0.18.3

# %% [markdown]
# <a href="cdo" id="cdo"></a>
# ## cdo, nco, and related
#
# Some packages should be used from the shell!

# %% [markdown]
# ### cdo package
#
# https://code.mpimet.mpg.de/projects/cdo/wiki/Tutorial

# %%
# this won't work:
#import cdo

# it will tell us:
# ModuleNotFoundError: No module named 'cdo'

# %% [markdown]
# This package has an executable in the bin directory of the current env, and must be run from the shell

# %%
# !which cdo
# Out:
# /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/bin/cdo

# %% [markdown]
# instead of importing a package, you must just use the cdo commands from the shell, as follows:

# %%
# !cdo -h
# Out:
# usage : cdo  [Options]  Operator1  [-Operator2  [-OperatorN]]
#
#   Options:
#     -a             Generate an absolute time axis
#     -A             Dry run that shows processed cdo call
#     --attribs [arbitrary/filesOnly/onlyFirst/noOutput/obase]
#     -b <nbits>     Set the number of bits for the output precision
#                    (I8/I16/I32/F32/F64 for nc1/nc2/nc4/nc4c/nc5; U8/U16/U32 for nc4/nc4c/nc5; F32/F64 for grb2/srv/ext/ieg; P1 - P24 for grb1/grb2)
#                    Add L or B to set the byteorder to Little or Big endian
#     --cmor         CMOR conform NetCDF output
#     -C, --color    Set behaviour of colorized output messages <auto,no,all>
#     --eccodes      Use ecCodes to decode/encode GRIB1 messages
#     --enableexcept <except>
#                    Set individual floating-point traps (DIVBYZERO, INEXACT, INVALID, OVERFLOW, UNDERFLOW, ALL_EXCEPT)
#     -f, --format <format>
#                    Format of the output file. (grb1/grb2/nc1/nc2/nc4/nc4c/nc5/srv/ext/ieg)
#     -g <grid>      Set default grid name or file. Available grids:
#                    F<XXX>, t<RES>, tl<RES>, global_<DXY>, r<NX>x<NY>, g<NX>x<NY>, gme<NI>, lon=<LON>/lat=<LAT>
#     -h, --help     Help information for the operators
#     --no_history   Do not append to NetCDF "history" global attribute
#     --netcdf_hdr_pad, --hdr_pad, --header_pad <nbr>
#                    Pad NetCDF output header with nbr bytes
#     -k <chunktype> NetCDF4 chunk type: auto, grid or lines
#     -L             Lock IO (sequential access)
#     -M             Switch to indicate that the I/O streams have missing values
#     -m <missval>   Set the missing value of non NetCDF files (default: -9e+33)
#     -O             Overwrite existing output file, if checked
#     --operators    List of all operators
#     --pedantic     Warnings count as errors
#     -P <nthreads>  Set number of OpenMP threads
#     --percentile <method>
#                    Percentile method: nrank, nist, rtype8, numpy, numpy_lower, numpy_higher, numpy_nearest
#     --precision <float_digits[,double_digits]>
#                    Precision to use in displaying floating-point data (default: 7,15)
#     --reduce_dim   Reduce NetCDF dimensions
#     --no_remap_weights Switch off generation of remap weights
#     -R, --regular  Convert GRIB1 data from global reduced to regular Gaussian grid (cgribex only)
#     -r             Generate a relative time axis
#     -S             Create an extra output stream for the module TIMSTAT. This stream
#                    contains the number of non missing values for each output period.
#     -s, --silent   Silent mode
#     --seed <seed>  Seed for a new sequence of pseudo-random numbers.
#     --sortname     Alphanumeric sorting of NetCDF parameter names
#     -t <codetab>   Set GRIB1 default parameter code table name or file (cgribex only)
#                    Predefined tables:  echam4 echam5 echam6 mpiom1 ecmwf remo cosmo002 cosmo201 cosmo202 cosmo203 cosmo205 cosmo250
#     --timestat_date <srcdate>
#                    Target timestamp (temporal statistics): first, middle, midhigh or last source timestep.
#     -V, --version  Print the version number
#     -v, --verbose  Print extra details for some operators
#     -w             Disable warning messages
#     --worker <num> Number of worker to decode/decompress GRIB records
#     -z szip        SZIP compression of GRIB1 records
#        aec         AEC compression of GRIB2 records
#        jpeg        JPEG compression of GRIB2 records
#         zip[_1-9]  Deflate compression of NetCDF4 variables
#
#   Operators:
#     Use option --operators for a list of all operators.
#
#   CDO version 1.9.9, Copyright (C) 2003-2020 Uwe Schulzweida
#   This is free software and comes with ABSOLUTELY NO WARRANTY
#   Report bugs to <https://mpimet.mpg.de/cdo>

# %%
# !cdo -V
# Out:
# Climate Data Operators version 1.9.9 (https://mpimet.mpg.de/cdo)
# System: x86_64-conda-linux-gnu
# CXX Compiler: /home/conda/feedstock_root/build_artifacts/cdo_1604652667339/_build_env/bin/x86_64-conda-linux-gnu-c++ -fPIC -DPIC -g -O2 -std=c++11 -fopenmp -DACCEPT_USE_OF_DEPRECATED_PROJ_API_H=1  -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/include -fdebug-prefix-map=/home/conda/feedstock_root/build_artifacts/cdo_1604652667339/work=/usr/local/src/conda/cdo-1.9.9 -fdebug-prefix-map=/apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09=/usr/local/src/conda-prefix -fopenmp -pthread
# CXX version : unknown
# C Compiler: /home/conda/feedstock_root/build_artifacts/cdo_1604652667339/_build_env/bin/x86_64-conda-linux-gnu-cc -DACCEPT_USE_OF_DEPRECATED_PROJ_API_H=1  -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/include -fdebug-prefix-map=/home/conda/feedstock_root/build_artifacts/cdo_1604652667339/work=/usr/local/src/conda/cdo-1.9.9 -fdebug-prefix-map=/apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09=/usr/local/src/conda-prefix -fopenmp -pthread -pthread
# C version : unknown
# F77 Compiler: /home/conda/feedstock_root/build_artifacts/cdo_1604652667339/_build_env/bin/x86_64-conda-linux-gnu-gfortran -fopenmp -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/include -fdebug-prefix-map=/home/conda/feedstock_root/build_artifacts/cdo_1604652667339/work=/usr/local/src/conda/cdo-1.9.9 -fdebug-prefix-map=/apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09=/usr/local/src/conda-prefix
# F77 version : GNU Fortran (crosstool-NG 1.24.0.133_b0863d8_dirty) 9.3.0
# Features: 31GB 16threads C++11 OpenMP45 Fortran PTHREADS HDF5 NC4/HDF5/threadsafe OPeNDAP UDUNITS2 PROJ XML2 CURL FFTW3 SSE3
# Libraries: HDF5/1.10.6 proj/7.2.0 xml2/2.9.10 curl/7.75.0(h7.71.1)
# Filetypes: srv ext ieg grb1 grb2 nc1 nc2 nc4 nc4c nc5
#      CDI library version : 1.9.9
#  cgribex library version : 1.9.5
#  ecCodes library version : 2.21.0
#   NetCDF library version : 4.7.4 of Dec 14 2020 16:14:56 $
#     hdf5 library version : 1.10.6 threadsafe
#     exse library version : 1.4.1
#     FILE library version : 1.9.1

# %% [markdown]
# For more information, refer to [About your PATH](#path), below.

# %% [markdown]
# ### pynco
#
# https://kandi.openweaver.com/python/nco/pynco
#
# For `pynco`, the expected import does not work:

# %%
# this import throws an error
# import pynco

#ModuleNotFoundError: No module named 'pynco'

# %% [markdown]
# instead, just do as follows:

# %%
from nco import Nco

# %% [markdown]
# ### nco
#
# Unlike cdo and pynco, however, nco is a package that can be imported:

# %%
import nco

# %% [markdown]
# <a href="geocat" id="geocat"></a>
# ## Using `geocat-viz` and other NCAR packages

# %% [markdown]
# In the current install, we have:
#
# - geocat-viz
# - geocat-comp
# - geocat-f2py
#
# Others are available but not installed here:
#
# - geocat-examples
# - geocat-datafiles
# - wrf-python

# %% [markdown]
# To use the `geocat` packages:

# %%
from geocat import viz

# %%
from geocat import comp

# %%
from geocat import f2py

# %% [markdown]
# Documentation:
#
# - https://geocat.ucar.edu/pages/software.html
#
# - https://geocat-examples.readthedocs.io/en/latest/index.html

# %% [markdown]
# <a href="geos" id="geos"></a>
# ## Using geos

# %% [markdown]
# First you must ask: "which geos?"
#
# - `pygeos` package: a C/Python library with vectorized geometry functions
# - `geos` package: a python-based server for creating Google Earth overlays of tiled maps.
#
# ### installed:
#
# Installed here: GEOS: Google Earth Overlay Server
#
# https://geos.readthedocs.io/en/latest/index.html
#
# ### not installed:
#
# Not installed here: PyGeos: The Python/C version of GEOS (Geometry Engine - Open Source), a C++ port of the JTS Topology Suite (JTS). GEOS is a project of OSGeo.
#
# https://pygeos.readthedocs.io/en/latest/index.html

# %%
# yes, we can:
import geos

# %% [markdown]
# The most obvious way to use `geos`: from the Workspace10 command line.
#
# https://geos.readthedocs.io/en/latest/users.html#usage

# %%
# !which geos
# Out:
# /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/bin/geos

# %% [markdown]
# The `geos` command starts a local webserver and provides a means of connection via localhost and a port.

# %%
# !geos
# Out:
#  * Serving Flask app 'geos' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:5000/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# <a href="globus" id="globus"></a>
# ## Globus sdk package

# %%
# the package is called globus-sdk, but the import uses an underscore!
import globus_sdk

# %% [markdown]
# ## Additional info

# %% [markdown]
# Some stuff about packages and modules in python:
#
#     https://www.devdungeon.com/content/python-import-syspath-and-pythonpath-tutorial

# %% [markdown]
# <a href="path" id="path"></a>
# ## Current `$PATH`
#
# So long as the env's bin directory is listed in our path environment variable in this kernel, we can easily run anything installed there by just calling it by name, like we did with ```!cdo```
# above. The current PATH contains the directories shown here:

# %%
# !echo $PATH
# Out:
# /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/bin:/apps/share64/debian10/anaconda/anaconda-6/bin:/apps/jupyter6deb10/r6/bin:/bin:/usr/bin:/usr/bin/X11:/sbin:/usr/sbin

# %% [markdown]
# ### The env's bin directory
#
# Here are the executables that the current kernel's env install makes possible. Since this location is found first in the PATH it will be searched first:

# %%
# !ls /apps/share64/debian10/anaconda/anaconda-6/envs/geospatial-2021-09/bin/
# Out:
# 2to3
# 2to3-3.7
# acountry
# activate-global-python-argcomplete
# adig
# aec
# ahost
# AnalyzeMap
# applygeo
# ApplyOfflineMap
# aserver
# assistant
# autopoint
# bokeh
# brotli
# bufr_compare
# bufr_compare_dir
# bufr_copy
# bufr_count
# bufr_dump
# bufr_filter
# bufr_get
# bufr_ls
# bufr_set
# bunzip2
# bzcat
# bzcmp
# bzdiff
# bzegrep
# bzfgrep
# bzgrep
# bzip2
# bzip2recover
# bzless
# bzmore
# cairo-trace
# CalculateDiffNorms
# canbusutil
# captoinfo
# cbrunsli
# cct
# cdo
# certtool
# certutil
# chardetect
# cjpeg
# clear
# clusterdb
# CoarsenRectilinearData
# codes_bufr_filter
# codes_count
# codes_info
# codes_parser
# codes_split_file
# colorcet
# compile_et
# ConvertExodusToSCRIP
# ConvertSCRIPToExodus
# createdb
# CreateDOMDocument
# createuser
# c_rehash
# cs2cs
# curl
# curl-config
# curve_keygen
# dap-config
# dap-config-pkgconfig
# dask-scheduler
# dask-ssh
# dask-worker
# datashader
# dbrunsli
# dbus-cleanup-sockets
# dbus-daemon
# dbus-launch
# dbus-monitor
# dbus-run-session
# dbus-send
# dbus-test-tool
# dbus-update-activation-environment
# dbus-uuidgen
# derb
# designer
# dhdt.py
# djpeg
# DOMCount
# DOMPrint
# dropdb
# dropuser
# ecpg
# EnumVal
# envsubst
# epsg_tr.py
# ESMF_PrintInfo
# ESMF_PrintInfoC
# ESMF_Regrid
# ESMF_RegridWeightGen
# ESMF_Scrip2Unstruct
# ESMF_WebServController
# esri2wkt.py
# f2py
# f2py3
# f2py3.7
# fax2ps
# fax2tiff
# fc-cache
# fc-cat
# fc-conflist
# fc-list
# fc-match
# fc-pattern
# fc-query
# fc-scan
# fc-validate
# featuretrack.py
# ffmpeg
# ffprobe
# fftwf-wisdom
# fftwl-wisdom
# fftw-wisdom
# fftw-wisdom-to-conf
# fio
# fitscopy
# fixqt4headers.pl
# flask
# fpack
# freetype-config
# funpack
# gapplication
# gcps2vec.py
# gcps2wld.py
# gdal2tiles.py
# gdal2xyz.py
# gdaladdo
# gdal_auth.py
# gdalbuildvrt
# gdal_calc.py
# gdalchksum.py
# gdalcompare.py
# gdal-config
# gdal_contour
# gdal_create
# gdaldem
# gdal_edit.py
# gdalenhance
# gdal_fillnodata.py
# gdal_grid
# gdalident.py
# gdalimport.py
# gdalinfo
# gdallocationinfo
# gdalmanage
# gdalmdiminfo
# gdalmdimtranslate
# gdal_merge.py
# gdalmove.py
# gdal_pansharpen.py
# gdal_polygonize.py
# gdal_proximity.py
# gdal_rasterize
# gdal_retile.py
# gdal_sieve.py
# gdalsrsinfo
# gdaltindex
# gdaltransform
# gdal_translate
# gdal_viewshed
# gdalwarp
# gdbus
# gdbus-codegen
# genbrk
# gencfu
# gencnval
# gendict
# GenerateConnectivityFile
# GenerateCSMesh
# GenerateGLLMetaData
# GenerateICOMesh
# GenerateLambertConfConicMesh
# GenerateOfflineMap
# GenerateOverlapMesh
# GenerateOverlapMesh_v1
# GenerateRLLMesh
# GenerateTestData
# GenerateTransectMesh
# GenerateTransposeMap
# GenerateUTMMesh
# GenerateVolumetricMesh
# genrb
# geod
# geos
# geos-config
# geotifcp
# geoviews
# getdap
# getdap4
# gettext
# gettextize
# gettext.sh
# gie
# gif2h5
# gif2hdf
# gif2rgb
# gifbuild
# gifclrmp
# giffix
# giftext
# giftool
# gio
# gio-querymodules
# glib-compile-resources
# glib-compile-schemas
# glib-genmarshal
# glib-gettextize
# glib-mkenums
# gnmanalyse
# gnmmanage
# gnutls-cli
# gnutls-cli-debug
# gnutls-serv
# gobject-query
# gresource
# grib2ppm
# grib_compare
# grib_copy
# grib_count
# grib_dump
# grib_filter
# grib_get
# grib_get_data
# grib_histogram
# grib_index_build
# grib_ls
# grib_merge
# grib_set
# grib_to_netcdf
# gsettings
# gsl-config
# gsl-histogram
# gsl-randist
# gss-client
# gst-device-monitor-1.0
# gst-discoverer-1.0
# gst-inspect-1.0
# gst-launch-1.0
# gst-play-1.0
# gst-stats-1.0
# gst-typefind-1.0
# gtester
# gtester-report
# gts_compare
# gts_copy
# gts_count
# gts_dump
# gts_filter
# gts_get
# gts_ls
# h264dec
# h264enc
# h2load
# h4cc
# h4_ncdump
# h4_ncgen
# h4redeploy
# h52gif
# h5c++
# h5cc
# h5clear
# h5copy
# h5debug
# h5diff
# h5dump
# h5fc
# h5format_convert
# h5import
# h5jam
# h5ls
# h5mkgrp
# h5perf_serial
# h5redeploy
# h5repack
# h5repart
# h5stat
# h5unjam
# h5watch
# hb-ot-shape-closure
# hb-shape
# hb-subset
# hb-view
# hdf24to8
# hdf2gif
# hdf2jpeg
# hdf8to24
# hdfcomp
# hdfed
# hdfimport
# hdfls
# hdfpack
# hdftopal
# hdftor8
# hdfunpac
# hdiff
# hdp
# holoviews
# hrepack
# iconv
# icu-config
# icuinfo
# idle3
# idle3.7
# imagecodecs
# imageio_download_bin
# imageio_remove_bin
# imcopy
# imgcmp
# imginfo
# infocmp
# infotocap
# initdb
# intake
# intake-server
# invgeod
# invproj
# iptest
# iptest3
# ipython
# ipython3
# isce.log
# jasper
# jpeg2hdf
# jpegtran
# jpgicc
# jp.py
# jsonschema
# jupyter
# jupyter-bundlerextension
# jupyter-kernel
# jupyter-kernelspec
# jupyter-migrate
# jupyter-nbconvert
# jupyter-nbextension
# jupyter-notebook
# jupyter-run
# jupyter-serverextension
# jupyter-troubleshoot
# jupyter-trust
# JxrDecApp
# JxrEncApp
# k5srvutil
# kadmin
# kdestroy
# kea-config
# kinit
# klist
# kpasswd
# krb5-config
# ksu
# kswitch
# ktutil
# kvno
# lame
# lconvert
# libdeflate-gunzip
# libdeflate-gzip
# libpng16-config
# libpng-config
# linguist
# linkicc
# listgeo
# lrelease
# lsm2bin
# lupdate
# lz4
# lz4c
# lz4cat
# lzcat
# lzcmp
# lzdiff
# lzegrep
# lzfgrep
# lzgrep
# lzless
# lzma
# lzmadec
# lzmainfo
# lzmore
# makeconv
# makegeo
# markdown_py
# MemParse
# MeshToTxt
# metar_compare
# metar_copy
# metar_dump
# metar_filter
# metar_get
# metar_ls
# mkgraticule.py
# moc
# msgattrib
# msgcat
# msgcmp
# msgcomm
# msgconv
# msgen
# msgexec
# msgfilter
# msgfmt
# msggrep
# msginit
# msgmerge
# msgunfmt
# msguniq
# mwm
# nc3tonc4
# nc4tonc3
# ncap2
# ncatted
# ncbo
# ncclimo
# nc-config
# nccopy
# ncdiff
# ncdump
# ncea
# ncecat
# nces
# ncflint
# ncgen
# ncgen3
# ncinfo
# ncks
# ncpdq
# ncra
# ncrcat
# ncremap
# ncrename
# ncurses6-config
# ncursesw6-config
# ncwa
# nearblack
# nettle-hash
# nettle-lfib-stream
# nettle-pbkdf2
# nf-config
# ngettext
# nghttp
# nghttpd
# nghttpx
# node
# npm
# npx
# nspr-config
# nss-config
# numba
# ocsptool
# ogr2ogr
# ogrinfo
# ogrlineref
# ogrmerge.py
# ogrtindex
# oid2name
# opencv_annotation
# opencv_interactive-calibration
# opencv_model_diagnostics
# opencv_version
# opencv_visualisation
# opencv_waldboost_detector
# openssl
# opj_compress
# opj_decompress
# opj_dump
# pal2rgb
# paltohdf
# pandoc
# panel
# pcre-config
# pcregrep
# pcretest
# pct2rgb.py
# pdfattach
# pdfdetach
# pdffonts
# pdfimages
# pdfinfo
# pdfseparate
# pdftocairo
# pdftohtml
# pdftoppm
# pdftops
# pdftotext
# pdfunite
# pg_archivecleanup
# pg_basebackup
# pgbench
# pg_checksums
# pg_config
# pg_controldata
# pg_ctl
# pg_dump
# pg_dumpall
# pg_isready
# pg_receivewal
# pg_recvlogical
# pg_resetwal
# pg_restore
# pg_rewind
# pg_standby
# pg_test_fsync
# pg_test_timing
# pg_upgrade
# pg_verifybackup
# pg_waldump
# pint-convert
# pip
# pip3
# pixeltool
# pk12util
# pkcs1-conv
# pkgdata
# pngfix
# png-fix-itxt
# postgres
# postmaster
# PParse
# ppm2tiff
# proj
# projinfo
# projsync
# protoc
# psicc
# psktool
# psql
# PSVIWriter
# __pycache__
# pycc
# pydoc
# pydoc3
# pydoc3.7
# pygmentize
# pylupdate5
# pyproj
# pyrcc5
# python
# python3
# python3.7
# python3.7-config
# python3.7m
# python3.7m-config
# python3-config
# python-argcomplete-check-easy-install-script
# python-argcomplete-tcsh
# pyuic5
# pyvenv
# pyvenv-3.7
# qcollectiongenerator
# qdbus
# qdbuscpp2xml
# qdbusviewer
# qdbusxml2cpp
# qdistancefieldgenerator
# qdoc
# qgltf
# qhelpgenerator
# qlalr
# qmake
# qml
# qmlcachegen
# qmleasing
# qmlimportscanner
# qmllint
# qmlmin
# qmlplugindump
# qmlpreview
# qmlprofiler
# qmlscene
# qmltestrunner
# qscxmlc
# qtattributionsscanner
# qt.conf
# qtdiag
# qtpaths
# qtplugininfo
# qvkgen
# qwebengine_convert_dict
# r8tohdf
# raw2tiff
# rcc
# rdjpgcom
# recode-sr-latin
# Redirect
# register-python-argcomplete
# reindexdb
# repc
# reset
# rgb2pct.py
# rio
# ristosds
# runxlrd.py
# sat-search
# sat-stac
# SAX2Count
# SAX2Print
# SAXCount
# SAXPrint
# sclient
# SCMPrint
# send2trash
# SEnumVal
# setup_vars_opencv4.sh
# sexp-conv
# ShpToMesh
# sim_client
# sip
# skivi
# smem
# sqlite3
# sqlite3_analyzer
# srptool
# StdInParse
# syncqt.pl
# tabs
# tclsh
# tclsh8.6
# test
# testepsg
# tic
# tiff2bw
# tiff2fsspec
# tiff2pdf
# tiff2ps
# tiff2rgba
# tiffcmp
# tiffcomment
# tiffcp
# tiffcrop
# tiffdither
# tiffdump
# tifffile
# tiffinfo
# tiffmedian
# tiffset
# tiffsplit
# tificc
# tigge_check
# tmrdemo
# toe
# tput
# tqdm
# transicc
# tset
# tzselect
# udunits2
# uic
# uil
# unlz4
# unlzma
# unxz
# unzstd
# uuclient
# uuid
# uuid-config
# vacuumdb
# vacuumlo
# VerticalInterpolate
# vmake
# vshow
# webpinfo
# webpmux
# wheel
# wish
# wish8.6
# wrjpgcom
# x264
# x86_64-conda_cos6-linux-gnu-addr2line
# x86_64-conda_cos6-linux-gnu-ar
# x86_64-conda_cos6-linux-gnu-as
# x86_64-conda_cos6-linux-gnu-c89
# x86_64-conda_cos6-linux-gnu-c99
# x86_64-conda_cos6-linux-gnu-cc
# x86_64-conda_cos6-linux-gnu-c++filt
# x86_64-conda_cos6-linux-gnu-cpp
# x86_64-conda_cos6-linux-gnu-dwp
# x86_64-conda_cos6-linux-gnu-elfedit
# x86_64-conda_cos6-linux-gnu-f95
# x86_64-conda_cos6-linux-gnu-gcc
# x86_64-conda_cos6-linux-gnu-gcc-ar
# x86_64-conda_cos6-linux-gnu-gcc-nm
# x86_64-conda_cos6-linux-gnu-gcc-ranlib
# x86_64-conda_cos6-linux-gnu-gcov
# x86_64-conda_cos6-linux-gnu-gcov-dump
# x86_64-conda_cos6-linux-gnu-gcov-tool
# x86_64-conda_cos6-linux-gnu-gfortran
# x86_64-conda_cos6-linux-gnu-gprof
# x86_64-conda_cos6-linux-gnu-ld
# x86_64-conda_cos6-linux-gnu-ld.bfd
# x86_64-conda_cos6-linux-gnu-ld.gold
# x86_64-conda_cos6-linux-gnu-nm
# x86_64-conda_cos6-linux-gnu-objcopy
# x86_64-conda_cos6-linux-gnu-objdump
# x86_64-conda_cos6-linux-gnu-ranlib
# x86_64-conda_cos6-linux-gnu-readelf
# x86_64-conda_cos6-linux-gnu-size
# x86_64-conda_cos6-linux-gnu-strings
# x86_64-conda_cos6-linux-gnu-strip
# x86_64-conda-linux-gnu-addr2line
# x86_64-conda-linux-gnu-ar
# x86_64-conda-linux-gnu-as
# x86_64-conda-linux-gnu-c89
# x86_64-conda-linux-gnu-c99
# x86_64-conda-linux-gnu-cc
# x86_64-conda-linux-gnu-c++filt
# x86_64-conda-linux-gnu-cpp
# x86_64-conda-linux-gnu-dwp
# x86_64-conda-linux-gnu-elfedit
# x86_64-conda-linux-gnu-f95
# x86_64-conda-linux-gnu-gcc
# x86_64-conda-linux-gnu-gcc-ar
# x86_64-conda-linux-gnu-gcc-nm
# x86_64-conda-linux-gnu-gcc-ranlib
# x86_64-conda-linux-gnu-gcov
# x86_64-conda-linux-gnu-gcov-dump
# x86_64-conda-linux-gnu-gcov-tool
# x86_64-conda-linux-gnu-gfortran
# x86_64-conda-linux-gnu-gprof
# x86_64-conda-linux-gnu-ld
# x86_64-conda-linux-gnu-ld.bfd
# x86_64-conda-linux-gnu-ld.gold
# x86_64-conda-linux-gnu-nm
# x86_64-conda-linux-gnu-objcopy
# x86_64-conda-linux-gnu-objdump
# x86_64-conda-linux-gnu-ranlib
# x86_64-conda-linux-gnu-readelf
# x86_64-conda-linux-gnu-size
# x86_64-conda-linux-gnu-strings
# x86_64-conda-linux-gnu-strip
# xgettext
# XInclude
# xkbcli
# xmbind
# xml2-config
# xmlcatalog
# xmllint
# xmlpatterns
# xmlpatternsvalidator
# xmlwf
# xz
# xzcat
# xzcmp
# xzdec
# xzdiff
# xzegrep
# xzfgrep
# xzgrep
# xzless
# xzmore
# zdump
# zfp
# zic
# zopfli
# zopflipng
# zstd
# zstdcat
# zstdgrep
# zstdless
# zstdmt

# %% [markdown]
# You can see that `cdo` is in that directory.

# %% [markdown]
# ### Anaconda's bin directory
#
# Here are the executables that the anaconda install makes possible. Any executable not found in the env's bin will be searched for here, next:

# %%
# !ls /apps/share64/debian10/anaconda/anaconda-6/bin/
# Out:
# 2to3				    lzmadec
# 2to3-3.7			    lzmainfo
# activate			    lzmore
# anaconda			    make
# anaconda-navigator		    makeconv
# anaconda-project		    moc
# asadmin				    mturk
# assistant			    myisamchk
# bagit.py			    myisam_ftdump
# binstar				    myisamlog
# black				    myisampack
# blackd				    my_print_defaults
# blaze-server			    mysql
# bokeh				    mysqladmin
# bsdcat				    mysqlbinlog
# bsdcpio				    mysqlcheck
# bsdtar				    mysql_client_test
# bundle_image			    mysql_client_test_embedded
# bunzip2				    mysql_config
# bzcat				    mysql_config_editor
# bzcmp				    mysqld
# bzdiff				    mysqld_multi
# bzegrep				    mysqld_safe
# bzfgrep				    mysqldump
# bzgrep				    mysqldumpslow
# bzip2				    mysql_embedded
# bzip2recover			    mysqlimport
# bzless				    mysql_install_db
# bzmore				    mysql_plugin
# c89				    mysqlpump
# c99				    mysql_secure_installation
# cairo-trace			    mysql.server
# canbusutil			    mysqlshow
# captoinfo			    mysqlslap
# celery				    mysql_ssl_rsa_setup
# certtool			    mysqltest
# cfadmin				    mysqltest_embedded
# chardetect			    mysql_tzinfo_to_sql
# cjpeg				    mysql_upgrade
# clear				    mysqlxtest
# compile_et			    navigator-updater
# conda				    ncursesw6-config
# conda-build			    nettle-hash
# conda-convert			    nettle-lfib-stream
# conda-debug			    nettle-pbkdf2
# conda-develop			    node
# conda-env			    nosetests
# conda-index			    npm
# conda-inspect			    npx
# conda-metapackage		    numba
# conda-render			    ocsptool
# conda-server			    odbc_config
# conda-skeleton			    odbcinst
# conda-verify			    odo
# cookiecutter			    openssl
# coverage			    pal2rgb
# coverage3			    pandoc
# coverage-3.7			    pandoc-citeproc
# cph				    pango-list
# cq				    pango-view
# c_rehash			    papermill
# curl				    pasteurize
# curl-config			    patchelf
# curve_keygen			    pcre-config
# cwutil				    pcregrep
# cygdb				    pcretest
# cython				    pep8
# cythonize			    perror
# dask-mpi			    pip
# dask-remote			    pip3
# dask-scheduler			    pixeltool
# dask-ssh			    pkcs1-conv
# dask-submit			    pkgdata
# dask-worker			    pkginfo
# db_archive			    pngfix
# db_checkpoint			    png-fix-itxt
# db_deadlock			    ppm2tiff
# db_dump				    protoc
# db_hotbackup			    psktool
# db_load				    pt2to3
# db_log_verify			    ptdump
# db_printlog			    ptrepack
# db_recover			    pttree
# db_replicate			    punch
# db_stat				    pyami_sendmail
# db_tuner			    pybabel
# db_upgrade			    pycc
# dbus-cleanup-sockets		    pycodestyle
# dbus-daemon			    pydoc
# dbus-launch			    pydoc3
# dbus-monitor			    pydoc3.7
# dbus-run-session		    pyflakes
# dbus-send			    pygmentize
# dbus-test-tool			    pyjson5
# dbus-update-activation-environment  pylint
# dbus-uuidgen			    pylupdate5
# db_verify			    pyrcc5
# deactivate			    pyreverse
# derb				    py.test
# designer			    pytest
# djpeg				    python
# dltest				    python3
# dynamodb_dump			    python3.7
# dynamodb_load			    python3.7-config
# easy_install			    python3.7m
# elbadmin			    python3.7m-config
# epylint				    python3-config
# f2py				    pyuic5
# f2py3				    pyvenv
# f2py3.7				    pyvenv-3.7
# fax2ps				    qcollectiongenerator
# fax2tiff			    qdbus
# fc-cache			    qdbuscpp2xml
# fc-cat				    qdbusviewer
# fc-conflist			    qdbusxml2cpp
# fc-list				    qdoc
# fc-match			    qgltf
# fc-pattern			    qhelpconverter
# fc-query			    qhelpgenerator
# fc-scan				    qlalr
# fc-validate			    qmake
# fetch_file			    qml
# ffmpeg				    qmlcachegen
# ffprobe				    qmleasing
# fftwf-wisdom			    qmlimportscanner
# fftwl-wisdom			    qmllint
# fftw-wisdom			    qmlmin
# fftw-wisdom-to-conf		    qmlplugindump
# fits2bitmap			    qmlprofiler
# fitscheck			    qmlscene
# fitsdiff			    qmltestrunner
# fitsheader			    qscxmlc
# fitsinfo			    qtattributionsscanner
# fixqt4headers.pl		    qt.conf
# flask				    qtdiag
# freetype-config			    qtpaths
# fribidi				    qtplugininfo
# futurize			    qwebengine_convert_dict
# gapplication			    R
# gdbus				    raw2tiff
# gdbus-codegen			    rcc
# genbrk				    rdjpgcom
# gencfu				    repc
# gencnval			    replace
# gendict				    reset
# genrb				    resolveip
# get_objgraph			    resolve_stack_dump
# gif2h5				    rg
# gio				    route53
# gio-querymodules		    Rscript
# glacier				    rst2html4.py
# glib-compile-resources		    rst2html5.py
# glib-compile-schemas		    rst2html.py
# glib-genmarshal			    rst2latex.py
# glib-gettextize			    rst2man.py
# glib-mkenums			    rst2odt_prepstyles.py
# glue				    rst2odt.py
# glue-config			    rst2pseudoxml.py
# glue-deps			    rst2s5.py
# gnutls-cli			    rst2xetex.py
# gnutls-cli-debug		    rst2xml.py
# gnutls-serv			    rstpep2html.py
# gobject-query			    runxlrd.py
# gresource			    s3put
# gsettings			    samp_hub
# gsl-config			    sclient
# gsl-histogram			    sdbadmin
# gsl-randist			    sexp-conv
# gss-client			    showtable
# gst-device-monitor-1.0		    sim_client
# gst-discoverer-1.0		    sip
# gst-inspect-1.0			    skivi
# gst-launch-1.0			    slencheck
# gst-play-1.0			    sphinx-apidoc
# gst-stats-1.0			    sphinx-autogen
# gst-typefind-1.0		    sphinx-build
# gtester				    sphinx-quickstart
# gtester-report			    spyder
# h264dec				    sqlite3
# h264enc				    sqlite3_analyzer
# h52gif				    srptool
# h5c++				    sshtunnel
# h5cc				    start_jupyter
# h5clear				    start_jupyterlab
# h5copy				    symilar
# h5debug				    syncqt.pl
# h5diff				    tabs
# h5dump				    taskadmin
# h5fc				    tclsh
# h5format_convert		    tclsh8.6
# h5import			    tic
# h5jam				    tiff2bw
# h5ls				    tiff2pdf
# h5mkgrp				    tiff2ps
# h5perf_serial			    tiff2rgba
# h5redeploy			    tiffcmp
# h5repack			    tiffcp
# h5repart			    tiffcrop
# h5stat				    tiffdither
# h5unjam				    tiffdump
# h5watch				    tiffinfo
# hb-ot-shape-closure		    tiffmedian
# hb-shape			    tiffset
# hb-subset			    tiffsplit
# hb-view				    toe
# iconv				    tox
# icu-config			    tox-quickstart
# icuinfo				    tput
# idle3				    tqdm
# idle3.7				    tset
# infocmp				    uic
# infotocap			    undill
# innochecksum			    unlz4
# instance_events			    unlzma
# ipcluster			    unxz
# ipcontroller			    unzstd
# ipengine			    uuclient
# iptest				    vba_extract.py
# iptest3				    virtualenv
# ipython				    volint
# ipython3			    watchmedo
# isort				    wcslint
# isql				    wheel
# isympy				    wish
# iusql				    wish8.6
# jlpm				    wrjpgcom
# jpegtran			    x264
# jsonschema			    x86_64-conda_cos6-linux-gnu-addr2line
# jupyter				    x86_64-conda_cos6-linux-gnu-ar
# jupyter-bundlerextension	    x86_64-conda_cos6-linux-gnu-as
# jupyter-console			    x86_64-conda_cos6-linux-gnu-c++
# jupyter-kernel			    x86_64-conda_cos6-linux-gnu-cc
# jupyter-kernelspec		    x86_64-conda_cos6-linux-gnu-c++filt
# jupyter-lab			    x86_64-conda_cos6-linux-gnu-cpp
# jupyter-labextension		    x86_64-conda_cos6-linux-gnu-ct-ng.config
# jupyter-labhub			    x86_64-conda_cos6-linux-gnu-dwp
# jupyter-migrate			    x86_64-conda_cos6-linux-gnu-elfedit
# jupyter-nbconvert		    x86_64-conda_cos6-linux-gnu-f95
# jupyter-nbextension		    x86_64-conda_cos6-linux-gnu-g++
# jupyter-notebook		    x86_64-conda_cos6-linux-gnu-gcc
# jupyter-qtconsole		    x86_64-conda_cos6-linux-gnu-gcc-ar
# jupyter-run			    x86_64-conda_cos6-linux-gnu-gcc-nm
# jupyter-serverextension		    x86_64-conda_cos6-linux-gnu-gcc-ranlib
# jupyter-troubleshoot		    x86_64-conda_cos6-linux-gnu-gcov
# jupyter-trust			    x86_64-conda_cos6-linux-gnu-gcov-dump
# k5srvutil			    x86_64-conda_cos6-linux-gnu-gcov-tool
# kadmin				    x86_64-conda_cos6-linux-gnu-gfortran
# kdestroy			    x86_64-conda_cos6-linux-gnu-gfortran.bin
# keyring				    x86_64-conda_cos6-linux-gnu-gprof
# kill_instance			    x86_64-conda_cos6-linux-gnu-ld
# kinit				    x86_64-conda_cos6-linux-gnu-ld.bfd
# klist				    x86_64-conda_cos6-linux-gnu-ld.gold
# kpasswd				    x86_64-conda_cos6-linux-gnu-nm
# krb5-config			    x86_64-conda_cos6-linux-gnu-objcopy
# ksu				    x86_64-conda_cos6-linux-gnu-objdump
# kswitch				    x86_64-conda_cos6-linux-gnu-ranlib
# ktutil				    x86_64-conda_cos6-linux-gnu-readelf
# kvno				    x86_64-conda_cos6-linux-gnu-size
# lame				    x86_64-conda_cos6-linux-gnu-strings
# launch_instance			    x86_64-conda_cos6-linux-gnu-strip
# lconvert			    xml2-config
# libpng16-config			    xmlcatalog
# libpng-config			    xmllint
# libtool				    xmlpatterns
# libtoolize			    xmlpatternsvalidator
# linguist			    xmlwf
# list_instances			    xslt-config
# lrelease			    xsltproc
# lss3				    xz
# lupdate				    xzcat
# lz4				    xzcmp
# lz4c				    xzdec
# lz4cat				    xzdiff
# lz4_decompress			    xzegrep
# lzcat				    xzfgrep
# lzcmp				    xzgrep
# lzdiff				    xzless
# lzegrep				    xzmore
# lzfgrep				    zlib_decompress
# lzgrep				    zstd
# lzless				    zstdcat
# lzma				    zstdmt
